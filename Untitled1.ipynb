# %%
# %load_ext IPython.extensions.autoreload
# %autoreload 2
from latham.simulation import *
from latham.params import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle as pkl
import gzip
from matplotlib.animation import FuncAnimation
# Out:
# The IPython.extensions.autoreload extension is already loaded. To reload it, use:
#   %reload_ext IPython.extensions.autoreload

# %%
excitatory_firing_rates = []
inhib_firing_rates = []

for I in np.arange(3.6, 4.02, 0.02):
    print("-----------------")
    cell_params, synaptic_params, network_params = network_A(I, 1.4, 1.1, 0)
    
    #res = run_sim(cell_params, synaptic_params, network_params)
    #with gzip.open(f"pkls/fig7/I-{I}.pkl.gzip", "wb") as f:
    #    pkl.dump(res, f)
    
    res = None
    with gzip.open(f"pkls/fig7/I-{I}.pkl.gzip", "rb") as f:
        res = pkl.load(f)

    _, spikes, final_state = res
        
    excitatory_firing_rate = spikes[:,final_state.neuron_types].sum() / 100 / network_params.N / (1 - network_params.inhib_fraction)
    inhib_firing_rate = spikes[:,~final_state.neuron_types].sum() / 100 / network_params.N / network_params.inhib_fraction
    excitatory_firing_rates.append(excitatory_firing_rate)
    inhib_firing_rates.append(inhib_firing_rate)
    print(f"Excitatory firing rate: {excitatory_firing_rate}")
    print(f"Inhibitory firing rate: {inhib_firing_rate}")
# Out:
# -----------------
# Excitatory firing rate: 0.0007824999999999999
# Inhibitory firing rate: 0.001585
# -----------------
# Excitatory firing rate: 0.002325
# Inhibitory firing rate: 0.0056949999999999995
# -----------------
# Excitatory firing rate: 0.023555
# Inhibitory firing rate: 0.062215
# -----------------
# Excitatory firing rate: 0.0823275
# Inhibitory firing rate: 0.21864999999999998
# -----------------
# Excitatory firing rate: 0.06319374999999999
# Inhibitory firing rate: 0.167955
# -----------------
# Excitatory firing rate: 0.16085875
# Inhibitory firing rate: 0.428065
# -----------------
# Excitatory firing rate: 0.16960875
# Inhibitory firing rate: 0.45116
# -----------------
# Excitatory firing rate: 0.17363749999999997
# Inhibitory firing rate: 0.46193999999999996
# -----------------
# Excitatory firing rate: 0.1838075
# Inhibitory firing rate: 0.48866
# -----------------
# Excitatory firing rate: 0.18423750000000003
# Inhibitory firing rate: 0.492195
# -----------------
# Excitatory firing rate: 0.19485999999999998
# Inhibitory firing rate: 0.5186
# -----------------
# Excitatory firing rate: 0.19903625
# Inhibitory firing rate: 0.5306749999999999
# -----------------
# Excitatory firing rate: 0.2042725
# Inhibitory firing rate: 0.54471
# -----------------
# Excitatory firing rate: 0.21080875
# Inhibitory firing rate: 0.5609999999999999
# -----------------
# Excitatory firing rate: 0.21584874999999998
# Inhibitory firing rate: 0.57475
# -----------------
# Excitatory firing rate: 0.22110624999999998
# Inhibitory firing rate: 0.58926
# -----------------
# Excitatory firing rate: 0.22807374999999996
# Inhibitory firing rate: 0.6064149999999999
# -----------------
# Excitatory firing rate: 0.2322775
# Inhibitory firing rate: 0.617205
# -----------------
# Excitatory firing rate: 0.23779374999999997
# Inhibitory firing rate: 0.63235
# -----------------
# Excitatory firing rate: 0.24506375
# Inhibitory firing rate: 0.64955
# -----------------
# Excitatory firing rate: 0.24931625
# Inhibitory firing rate: 0.66092

# %%
plt.scatter(np.arange(3.6, 4.02, 0.02), np.array(excitatory_firing_rates))
plt.vlines([3.715, 3.75], 0, 0.25)

# %%
high_excitatory_firing_rates = []
low_excitatory_firing_rates = []

for I in np.arange(3.6, 4.02, 0.02):
    print("--------------")
    cell_params, synaptic_params, network_params = network_A(I, 1.4, 1.1, 0.01)
    
    #res = run_sim(cell_params, synaptic_params, network_params)
    #with gzip.open(f"pkls/fig7/SA-I-{I}.pkl.gzip", "wb") as f:
    #    pkl.dump(res, f)
    
    res = None
    with gzip.open(f"pkls/fig7/SA-I-{I}.pkl.gzip", "rb") as f:
        res = pkl.load(f)

    _, spikes, final_state = res

    bursts = spikes[np.any(spikes, axis=1),:]
    excitatory_firing_rate = bursts[:,final_state.neuron_types].sum() / (bursts.shape[0] / 1000) / network_params.N / (1 - network_params.inhib_fraction)
    high_excitatory_firing_rates.append(excitatory_firing_rate)
    if bursts.shape[0] < spikes.shape[0]:
        low_excitatory_firing_rates.append(0)
        print("Read low rate")
    else:
        low_excitatory_firing_rates.append(None)
    print(excitatory_firing_rate)
# Out:
# --------------
# Read low rate
# 0.8151041666666666
# --------------
# Read low rate
# 0.21920126353790612
# --------------
# Read low rate
# 0.24941479400749061
# --------------
# Read low rate
# 0.2409695817490494
# --------------
# Read low rate
# 0.2407130017974835
# --------------
# Read low rate
# 0.25223521320495185
# --------------
# Read low rate
# 0.22375054800526084
# --------------
# Read low rate
# 0.263362556561086
# --------------
# Read low rate
# 0.23079063555077356
# --------------
# Read low rate
# 0.2392093640772753
# --------------
# Read low rate
# 0.24426506543937868
# --------------
# Read low rate
# 0.25168945085585936
# --------------
# Read low rate
# 0.2565921214608125
# --------------
# Read low rate
# 0.26276606052776075
# --------------
# Read low rate
# 0.26637303715051697
# --------------
# Read low rate
# 0.27079822249110524
# --------------
# Read low rate
# 0.27768819318807514
# --------------
# Read low rate
# 0.2804488619587404
# --------------
# Read low rate
# 0.2900278417467802
# --------------
# Read low rate
# 0.2944196855285796
# --------------
# Read low rate
# 0.2988383566559024

# %%
plt.scatter(np.arange(3.6, 4.02, 0.02), np.array(high_excitatory_firing_rates))
plt.scatter(np.arange(3.6, 4.02, 0.02), np.array(low_excitatory_firing_rates))
plt.vlines([3.715, 3.75], 0, 0.2)
